# %%
import numpy as np
import matplotlib
import matplotlib.pylab as plt
import tensorflow as tf
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
matplotlib.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# ### 1. 다음 데이터를 잘 표현하는 회귀 모델을 찾으시오.
#
# $$y = f(x)$$

# %%
data = np.load('./nn_reg1.npz')
x_train = data['x_train']
y_train = data['y_train']
x_test = data['x_test']
y_test = data['y_test']

# %%
plt.plot(x_train,y_train,'ok', alpha = 0.7)
plt.plot(x_test,y_test,'rs', alpha=0.57)

# %%
features = np.array([[xval] for xval in x_train])
labels = np.array([[yval] for yval in y_train])

class MyModel(tf.keras.Model):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        num_hidden1 = 1750
        num_hidden2 = 1750
        num_hidden3 = 1750
        num_hidden4 = 1750
        num_hidden5 = 1750
        num_hidden6 = 1750
        num_hidden7 = 1750
        num_hidden8 = 1750
        
        self.W1 = tf.Variable(tf.random.normal([1,num_hidden1], seed = 2023), name ='weight1')
        self.b1 = tf.Variable(tf.zeros([num_hidden1]), name = 'bias1')
        
        self.W2 = tf.Variable(tf.random.normal([num_hidden1,num_hidden2], seed = 2023), name ='weight2')
        self.b2 = tf.Variable(tf.zeros([num_hidden2]), name = 'bias2')
        
        self.W3 = tf.Variable(tf.random.normal([num_hidden2,num_hidden3], seed = 2023), name ='weight3')
        self.b3 = tf.Variable(tf.zeros([num_hidden3]), name = 'bias3')
        
        self.W4 = tf.Variable(tf.random.normal([num_hidden3,num_hidden4], seed = 2023), name ='weight4')
        self.b4 = tf.Variable(tf.zeros([num_hidden4]), name = 'bias4')
        
        self.W5 = tf.Variable(tf.random.normal([num_hidden4,num_hidden5], seed = 2023), name ='weight5')
        self.b5 = tf.Variable(tf.zeros([num_hidden5]), name = 'bias5')
        
        self.W6 = tf.Variable(tf.random.normal([num_hidden5,num_hidden6], seed = 2023), name ='weight6')
        self.b6 = tf.Variable(tf.zeros([num_hidden6]), name = 'bias6')
        
        self.W7 = tf.Variable(tf.random.normal([num_hidden6,num_hidden7], seed = 2023), name ='weight7')
        self.b7 = tf.Variable(tf.zeros([num_hidden7]), name = 'bias7')
        
        self.W8 = tf.Variable(tf.random.normal([num_hidden7,num_hidden8], seed = 2023), name ='weight8')
        self.b8 = tf.Variable(tf.zeros([num_hidden8]), name = 'bias8')
        
        self.W9 = tf.Variable(tf.random.normal([num_hidden8,1], seed = 2023), name ='weight9')
        self.b9 = tf.Variable(tf.zeros([1]), name = 'bias9')
    
    def call(self, x):
        l1 = tf.matmul(x, self.W1) + self.b1
        h1 = tf.nn.tanh(l1)
        
        l2 = tf.matmul(h1, self.W2) + self.b2
        h2 = tf.nn.tanh(l2)
        
        l3 = tf.matmul(h2, self.W3) + self.b3
        h3 = tf.nn.tanh(l3)
        
        l4 = tf.matmul(h3, self.W4) + self.b4
        h4 = tf.nn.tanh(l4)
        
        l5 = tf.matmul(h4, self.W5) + self.b5
        h5 = tf.nn.tanh(l5)
        
        l6 = tf.matmul(h5, self.W6) + self.b6
        h6 = tf.nn.tanh(l6)
        
        l7 = tf.matmul(h6, self.W7) + self.b7
        h7 = tf.nn.tanh(l7)
        
        l8 = tf.matmul(h7, self.W8) + self.b8
        h8 = tf.nn.tanh(l8)
        
        yhat = tf.matmul(h8, self.W9) + self.b9
        return yhat

# %%
Epochs = 50000
batch_size = 2**15
lr = 0.0000005
optimizer = tf.keras.optimizers.legacy.Adagrad(lr)
loss = tf.keras.losses.MeanSquaredError()

# %%
np.random.seed(20)
shuffled_Id = np.arange(0,len(x_train))
np.random.shuffle(shuffled_Id)
shuffled_x_train = features[shuffled_Id]
shuffled_y_train = labels[shuffled_Id]

# %%
model = MyModel()

# %%
model.compile(optimizer=optimizer, loss=loss)

# %%
data3 = np.load('./pb3.npz')
x_train3 = data3['x_train']
y_train3 = data3['y_train']
z_train3 = data3['z_train']
target = data3['target'] # t

# %%
history = model.fit(shuffled_x_train, shuffled_y_train, epochs = Epochs, batch_size = batch_size, shuffle = False, verbose='auto')
# Out:
# Epoch 1/50000
# 1/1 [==============================] - 0s 120ms/step - loss: 712.0948
# Epoch 2/50000
# 1/1 [==============================] - 0s 240ms/step - loss: 676.7750
# Epoch 3/50000
# 1/1 [==============================] - 0s 216ms/step - loss: 661.5012
# Epoch 4/50000
# 1/1 [==============================] - 0s 193ms/step - loss: 685.8681
# Epoch 5/50000
# 1/1 [==============================] - 0s 183ms/step - loss: 737.9359
# Epoch 6/50000
# 1/1 [==============================] - 0s 191ms/step - loss: 591.1547
# Epoch 7/50000
# 1/1 [==============================] - 0s 186ms/step - loss: 612.3176
# Epoch 8/50000
# 1/1 [==============================] - 0s 185ms/step - loss: 697.5414
# Epoch 9/50000
# 1/1 [==============================] - 0s 183ms/step - loss: 763.5078
# Epoch 10/50000
# 1/1 [==============================] - 0s 178ms/step - loss: 656.1669
# Epoch 11/50000
# 1/1 [==============================] - 0s 179ms/step - loss: 707.4828
# Epoch 12/50000
# ...

# %%
yhat_= model(features)
yhat2 = model(x_test.reshape(-1,1))
loss2 = loss(y_test.reshape(-1,1),yhat2.numpy())
ax = plt.subplots(figsize=(8,5))
plt.plot(x_train, y_train, 'o')
plt.plot(features, yhat_.numpy(), 'r')
plt.plot(x_test.reshape(-1,1), yhat2.numpy(), 'kx')

plt.grid()
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('train: {}, test:{}'.format(history.history['loss'][-1],loss2))
plt.legend(['data', '$y$'])

# %%
model.summary()
# Out:
# Model: "my_model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
# Total params: 21455001 (81.84 MB)
# Trainable params: 21455001 (81.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
